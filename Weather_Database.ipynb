# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coordinates:
    city = citipy.nearest_city(coord[0], coord[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat                 = city_weather["coord"]["lat"]
        city_lng                 = city_weather["coord"]["lon"]
        city_max_temp            = city_weather["main"]["temp_max"]
        city_humidity            = city_weather["main"]["humidity"]
        city_clouds              = city_weather["clouds"]["all"]
        city_wind                = city_weather["wind"]["speed"]
        city_country             = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 1 | meshcherino
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | mehamn
# Processing Record 9 of Set 1 | beidao
# Processing Record 10 of Set 1 | olinda
# Processing Record 11 of Set 1 | arraial do cabo
# Processing Record 12 of Set 1 | chokurdakh
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | egvekinot
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | bo rai
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | abu samrah
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | andros town
# Processing Record 22 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | narsaq
# Processing Record 25 of Set 1 | pachino
# Processing Record 26 of Set 1 | puerto escondido
# Processing Record 27 of Set 1 | turinskaya sloboda
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | portobelo
# Processing Record 30 of Set 1 | antipovka
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | anadyr
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | san quintin
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | sao joao da barra
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | bahia honda
# Processing Record 43 of Set 1 | bay roberts
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | boende
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | asau
# Processing Record 49 of Set 1 | atar
# Processing Record 50 of Set 1 | petit goave
# Processing Record 1 of Set 2 | takoradi
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | touba
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | inirida
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | maxixe
# Processing Record 10 of Set 2 | labuhan
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | quartucciu
# Processing Record 14 of Set 2 | yulara
# Processing Record 15 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 2 | san patricio
# Processing Record 17 of Set 2 | baykit
# Processing Record 18 of Set 2 | kayes
# Processing Record 19 of Set 2 | komsomolskiy
# Processing Record 20 of Set 2 | husavik
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | coihaique
# Processing Record 23 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 24 of Set 2 | ishigaki
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | lorengau
# Processing Record 27 of Set 2 | chaihe
# Processing Record 28 of Set 2 | pemba
# Processing Record 29 of Set 2 | pisco
# Processing Record 30 of Set 2 | jaguaquara
# Processing Record 31 of Set 2 | perth
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | panjab
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | havoysund
# Processing Record 37 of Set 2 | salalah
# Processing Record 38 of Set 2 | tazovskiy
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | severo-kurilsk
# Processing Record 45 of Set 2 | ponta delgada
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | peterhead
# Processing Record 48 of Set 2 | ozinki
# Processing Record 49 of Set 2 | praia
# Processing Record 50 of Set 2 | boa vista
# Processing Record 1 of Set 3 | neepawa
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | bonga
# Processing Record 4 of Set 3 | talnakh
# Processing Record 5 of Set 3 | robore
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | vagur
# Processing Record 10 of Set 3 | san policarpo
# Processing Record 11 of Set 3 | port hedland
# Processing Record 12 of Set 3 | honiara
# Processing Record 13 of Set 3 | provideniya
# Processing Record 14 of Set 3 | barrow
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | da nang
# Processing Record 18 of Set 3 | nioro
# Processing Record 19 of Set 3 | bathsheba
# Processing Record 20 of Set 3 | kloulklubed
# Processing Record 21 of Set 3 | merritt island
# Processing Record 22 of Set 3 | lavrentiya
# Processing Record 23 of Set 3 | nyagan
# Processing Record 24 of Set 3 | katangli
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | samarai
# Processing Record 27 of Set 3 | mar del plata
# Processing Record 28 of Set 3 | terme
# Processing Record 29 of Set 3 | bilma
# Processing Record 30 of Set 3 | bethel
# Processing Record 31 of Set 3 | bonthe
# Processing Record 32 of Set 3 | talaya
# Processing Record 33 of Set 3 | bredasdorp
# Processing Record 34 of Set 3 | ukiah
# Processing Record 35 of Set 3 | olafsvik
# Processing Record 36 of Set 3 | upernavik
# Processing Record 37 of Set 3 | alice springs
# Processing Record 38 of Set 3 | yuyao
# Processing Record 39 of Set 3 | bela vista
# Processing Record 40 of Set 3 | chuy
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | lagoa
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | cayenne
# Processing Record 45 of Set 3 | mayo
# Processing Record 46 of Set 3 | puerto ayora
# Processing Record 47 of Set 3 | cabo san lucas
# Processing Record 48 of Set 3 | coquimbo
# Processing Record 49 of Set 3 | vao
# Processing Record 50 of Set 3 | ordynskoye
# Processing Record 1 of Set 4 | white rock
# Processing Record 2 of Set 4 | khilok
# Processing Record 3 of Set 4 | porbandar
# Processing Record 4 of Set 4 | ronneby
# Processing Record 5 of Set 4 | alofi
# Processing Record 6 of Set 4 | umm lajj
# Processing Record 7 of Set 4 | chaplynka
# Processing Record 8 of Set 4 | tarakan
# Processing Record 9 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 10 of Set 4 | santa maria
# Processing Record 11 of Set 4 | megion
# Processing Record 12 of Set 4 | kirakira
# Processing Record 13 of Set 4 | ayna
# Processing Record 14 of Set 4 | peleduy
# Processing Record 15 of Set 4 | buraydah
# Processing Record 16 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 4 | fairbanks
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | celestun
# Processing Record 20 of Set 4 | campbell river
# Processing Record 21 of Set 4 | sioux lookout
# Processing Record 22 of Set 4 | kupang
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | faanui
# Processing Record 25 of Set 4 | sault sainte marie
# Processing Record 26 of Set 4 | flinders
# Processing Record 27 of Set 4 | nakambala
# Processing Record 28 of Set 4 | hobart
# Processing Record 29 of Set 4 | iquique
# Processing Record 30 of Set 4 | agua preta
# Processing Record 31 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 4 | toora-khem
# Processing Record 33 of Set 4 | dali
# Processing Record 34 of Set 4 | gewane
# Processing Record 35 of Set 4 | henties bay
# Processing Record 36 of Set 4 | dien bien
# City not found. Skipping...
# Processing Record 37 of Set 4 | tual
# Processing Record 38 of Set 4 | nikolskoye
# Processing Record 39 of Set 4 | porto novo
# Processing Record 40 of Set 4 | zhaotong
# Processing Record 41 of Set 4 | chaa-khol
# City not found. Skipping...
# Processing Record 42 of Set 4 | cockburn town
# Processing Record 43 of Set 4 | camabatela
# Processing Record 44 of Set 4 | shimoda
# Processing Record 45 of Set 4 | daitari
# Processing Record 46 of Set 4 | angamacutiro
# City not found. Skipping...
# Processing Record 47 of Set 4 | mananjary
# Processing Record 48 of Set 4 | coachella
# Processing Record 49 of Set 4 | tessalit
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | bambous virieux
# Processing Record 2 of Set 5 | makakilo city
# Processing Record 3 of Set 5 | solone
# Processing Record 4 of Set 5 | lompoc
# Processing Record 5 of Set 5 | port lincoln
# Processing Record 6 of Set 5 | bukama
# Processing Record 7 of Set 5 | arrecife
# Processing Record 8 of Set 5 | brae
# Processing Record 9 of Set 5 | yellowknife
# Processing Record 10 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 5 | ostersund
# Processing Record 12 of Set 5 | paharpur
# Processing Record 13 of Set 5 | wiang sa
# Processing Record 14 of Set 5 | antibes
# Processing Record 15 of Set 5 | aklavik
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | along
# Processing Record 18 of Set 5 | victor harbor
# Processing Record 19 of Set 5 | komlo
# Processing Record 20 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 5 | walvis bay
# Processing Record 22 of Set 5 | the valley
# Processing Record 23 of Set 5 | geraldton
# Processing Record 24 of Set 5 | port alfred
# Processing Record 25 of Set 5 | canavieiras
# Processing Record 26 of Set 5 | comodoro rivadavia
# Processing Record 27 of Set 5 | caravelas
# Processing Record 28 of Set 5 | tasiilaq
# Processing Record 29 of Set 5 | padang
# Processing Record 30 of Set 5 | vila velha
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | port augusta
# Processing Record 33 of Set 5 | kruisfontein
# Processing Record 34 of Set 5 | mahebourg
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | lata
# Processing Record 37 of Set 5 | toumodi
# Processing Record 38 of Set 5 | korla
# Processing Record 39 of Set 5 | mao
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | dunedin
# Processing Record 42 of Set 5 | nanortalik
# Processing Record 43 of Set 5 | torbay
# Processing Record 44 of Set 5 | loudi
# Processing Record 45 of Set 5 | lagos
# Processing Record 46 of Set 5 | zachepylivka
# Processing Record 47 of Set 5 | daru
# Processing Record 48 of Set 5 | pacific grove
# Processing Record 49 of Set 5 | bengkulu
# Processing Record 50 of Set 5 | mali
# Processing Record 1 of Set 6 | timon
# Processing Record 2 of Set 6 | san ramon
# Processing Record 3 of Set 6 | do gonbadan
# Processing Record 4 of Set 6 | pokhara
# Processing Record 5 of Set 6 | jiuquan
# Processing Record 6 of Set 6 | rocha
# Processing Record 7 of Set 6 | zeya
# Processing Record 8 of Set 6 | kodiak
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | magistralnyy
# Processing Record 11 of Set 6 | taoudenni
# Processing Record 12 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 13 of Set 6 | pangani
# Processing Record 14 of Set 6 | nilai
# Processing Record 15 of Set 6 | hofn
# Processing Record 16 of Set 6 | esperance
# Processing Record 17 of Set 6 | mujiayingzi
# Processing Record 18 of Set 6 | constitucion
# Processing Record 19 of Set 6 | hit
# Processing Record 20 of Set 6 | ahipara
# Processing Record 21 of Set 6 | ostrovnoy
# Processing Record 22 of Set 6 | launceston
# Processing Record 23 of Set 6 | srednekolymsk
# Processing Record 24 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 6 | kapuskasing
# Processing Record 26 of Set 6 | feltre
# Processing Record 27 of Set 6 | riyadh
# Processing Record 28 of Set 6 | zhigansk
# Processing Record 29 of Set 6 | gikongoro
# Processing Record 30 of Set 6 | eureka
# Processing Record 31 of Set 6 | mikhaylovka
# Processing Record 32 of Set 6 | piacabucu
# Processing Record 33 of Set 6 | yuci
# Processing Record 34 of Set 6 | ambilobe
# Processing Record 35 of Set 6 | college
# Processing Record 36 of Set 6 | nuuk
# Processing Record 37 of Set 6 | shihezi
# Processing Record 38 of Set 6 | sulangan
# Processing Record 39 of Set 6 | barlinek
# Processing Record 40 of Set 6 | opuwo
# Processing Record 41 of Set 6 | erenhot
# Processing Record 42 of Set 6 | veraval
# Processing Record 43 of Set 6 | buchanan
# Processing Record 44 of Set 6 | la serena
# Processing Record 45 of Set 6 | antofagasta
# Processing Record 46 of Set 6 | bizhbulyak
# Processing Record 47 of Set 6 | arauca
# Processing Record 48 of Set 6 | murmashi
# Processing Record 49 of Set 6 | kavieng
# Processing Record 50 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 7 | la libertad
# Processing Record 2 of Set 7 | norman wells
# Processing Record 3 of Set 7 | champerico
# Processing Record 4 of Set 7 | requena
# Processing Record 5 of Set 7 | chimore
# Processing Record 6 of Set 7 | sortland
# Processing Record 7 of Set 7 | kerema
# Processing Record 8 of Set 7 | terra nova
# Processing Record 9 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 10 of Set 7 | antalaha
# Processing Record 11 of Set 7 | chapleau
# Processing Record 12 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 7 | cuauhtemoc
# Processing Record 14 of Set 7 | avera
# Processing Record 15 of Set 7 | imbituba
# Processing Record 16 of Set 7 | garm
# City not found. Skipping...
# Processing Record 17 of Set 7 | haifa
# Processing Record 18 of Set 7 | kismayo
# Processing Record 19 of Set 7 | mbandaka
# Processing Record 20 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 7 | quthing
# Processing Record 22 of Set 7 | fortuna
# Processing Record 23 of Set 7 | haines junction
# Processing Record 24 of Set 7 | corinto
# Processing Record 25 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 7 | mecca
# Processing Record 27 of Set 7 | hambantota
# Processing Record 28 of Set 7 | ketchikan
# Processing Record 29 of Set 7 | oussouye
# Processing Record 30 of Set 7 | kulachi
# Processing Record 31 of Set 7 | rangkasbitung
# Processing Record 32 of Set 7 | alyangula
# Processing Record 33 of Set 7 | lokosovo
# Processing Record 34 of Set 7 | iqaluit
# Processing Record 35 of Set 7 | sitka
# Processing Record 36 of Set 7 | gari
# Processing Record 37 of Set 7 | wakkanai
# Processing Record 38 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 7 | zhuzhou
# Processing Record 40 of Set 7 | camacha
# Processing Record 41 of Set 7 | zhangye
# Processing Record 42 of Set 7 | bealanana
# Processing Record 43 of Set 7 | male
# Processing Record 44 of Set 7 | neiafu
# Processing Record 45 of Set 7 | moerai
# Processing Record 46 of Set 7 | alamogordo
# Processing Record 47 of Set 7 | sumter
# Processing Record 48 of Set 7 | suntar
# Processing Record 49 of Set 7 | fare
# Processing Record 50 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 8 | vila
# Processing Record 2 of Set 8 | codrington
# Processing Record 3 of Set 8 | menongue
# Processing Record 4 of Set 8 | teya
# Processing Record 5 of Set 8 | port blair
# Processing Record 6 of Set 8 | gao
# Processing Record 7 of Set 8 | barcelos
# Processing Record 8 of Set 8 | greymouth
# Processing Record 9 of Set 8 | liverpool
# Processing Record 10 of Set 8 | jomalig
# City not found. Skipping...
# Processing Record 11 of Set 8 | upington
# Processing Record 12 of Set 8 | auki
# Processing Record 13 of Set 8 | port macquarie
# Processing Record 14 of Set 8 | basoko
# Processing Record 15 of Set 8 | saint-joseph
# Processing Record 16 of Set 8 | verkhovazhye
# Processing Record 17 of Set 8 | pangnirtung
# Processing Record 18 of Set 8 | isparta
# Processing Record 19 of Set 8 | salekhard
# Processing Record 20 of Set 8 | larsnes
# Processing Record 21 of Set 8 | den helder
# Processing Record 22 of Set 8 | rafsanjan
# Processing Record 23 of Set 8 | dubenskiy
# City not found. Skipping...
# Processing Record 24 of Set 8 | ornes
# Processing Record 25 of Set 8 | grindavik
# Processing Record 26 of Set 8 | beachwood
# Processing Record 27 of Set 8 | watsa
# Processing Record 28 of Set 8 | kallaste
# Processing Record 29 of Set 8 | cabras
# Processing Record 30 of Set 8 | kutum
# Processing Record 31 of Set 8 | biltine
# Processing Record 32 of Set 8 | phulpur
# Processing Record 33 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 34 of Set 8 | bereda
# Processing Record 35 of Set 8 | union
# Processing Record 36 of Set 8 | paamiut
# Processing Record 37 of Set 8 | eydhafushi
# Processing Record 38 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 8 | itarema
# Processing Record 40 of Set 8 | kongoussi
# Processing Record 41 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 8 | lasa
# Processing Record 43 of Set 8 | berbera
# Processing Record 44 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 8 | caraballeda
# Processing Record 46 of Set 8 | lousa
# Processing Record 47 of Set 8 | kasongo-lunda
# Processing Record 48 of Set 8 | half moon bay
# Processing Record 49 of Set 8 | gilbues
# Processing Record 50 of Set 8 | amuntai
# Processing Record 1 of Set 9 | tukrah
# Processing Record 2 of Set 9 | vikhorevka
# Processing Record 3 of Set 9 | ellensburg
# Processing Record 4 of Set 9 | cidreira
# Processing Record 5 of Set 9 | los llanos de aridane
# Processing Record 6 of Set 9 | pandan
# Processing Record 7 of Set 9 | graaff-reinet
# Processing Record 8 of Set 9 | madang
# Processing Record 9 of Set 9 | odessa
# Processing Record 10 of Set 9 | cabedelo
# Processing Record 11 of Set 9 | san lawrenz
# Processing Record 12 of Set 9 | contamana
# Processing Record 13 of Set 9 | gamba
# Processing Record 14 of Set 9 | uppsala
# Processing Record 15 of Set 9 | oranjemund
# Processing Record 16 of Set 9 | gat
# Processing Record 17 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 9 | sechura
# Processing Record 19 of Set 9 | roald
# Processing Record 20 of Set 9 | svetlyy
# Processing Record 21 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 9 | aleksandrov gay
# Processing Record 23 of Set 9 | genhe
# Processing Record 24 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 9 | camana
# Processing Record 26 of Set 9 | saint anthony
# Processing Record 27 of Set 9 | lazaro cardenas
# Processing Record 28 of Set 9 | nova olinda do norte
# Processing Record 29 of Set 9 | toguchin
# Processing Record 30 of Set 9 | otjiwarongo
# Processing Record 31 of Set 9 | kristianstad
# Processing Record 32 of Set 9 | kananga
# Processing Record 33 of Set 9 | omboue
# Processing Record 34 of Set 9 | kidal
# Processing Record 35 of Set 9 | santarem
# Processing Record 36 of Set 9 | eyl
# Processing Record 37 of Set 9 | waitati
# Processing Record 38 of Set 9 | havelock
# Processing Record 39 of Set 9 | tabou
# Processing Record 40 of Set 9 | safaga
# Processing Record 41 of Set 9 | bowen
# Processing Record 42 of Set 9 | algiers
# Processing Record 43 of Set 9 | kaduna
# Processing Record 44 of Set 9 | whitehorse
# Processing Record 45 of Set 9 | russkiy aktash
# Processing Record 46 of Set 9 | verkh-usugli
# Processing Record 47 of Set 9 | ayagoz
# Processing Record 48 of Set 9 | port hardy
# Processing Record 49 of Set 9 | yenagoa
# Processing Record 50 of Set 9 | hobyo
# Processing Record 1 of Set 10 | batsfjord
# Processing Record 2 of Set 10 | kushiro
# Processing Record 3 of Set 10 | koindu
# Processing Record 4 of Set 10 | orlik
# Processing Record 5 of Set 10 | blyth
# Processing Record 6 of Set 10 | huarmey
# Processing Record 7 of Set 10 | shaikhpura
# Processing Record 8 of Set 10 | altay
# Processing Record 9 of Set 10 | meadow lake
# Processing Record 10 of Set 10 | remontnoye
# Processing Record 11 of Set 10 | aranda de duero
# Processing Record 12 of Set 10 | luanda
# Processing Record 13 of Set 10 | sobolevo
# Processing Record 14 of Set 10 | yar-sale
# Processing Record 15 of Set 10 | soe
# Processing Record 16 of Set 10 | koulikoro
# Processing Record 17 of Set 10 | kobelyaky
# Processing Record 18 of Set 10 | slave lake
# Processing Record 19 of Set 10 | las varas
# Processing Record 20 of Set 10 | changji
# Processing Record 21 of Set 10 | freeport
# Processing Record 22 of Set 10 | borger
# Processing Record 23 of Set 10 | berlevag
# Processing Record 24 of Set 10 | chapais
# Processing Record 25 of Set 10 | kansk
# Processing Record 26 of Set 10 | kijang
# Processing Record 27 of Set 10 | sao gabriel da cachoeira
# Processing Record 28 of Set 10 | kuytun
# Processing Record 29 of Set 10 | mount gambier
# Processing Record 30 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 31 of Set 10 | lakes entrance
# Processing Record 32 of Set 10 | hasanabad
# Processing Record 33 of Set 10 | ilo
# Processing Record 34 of Set 10 | isangel
# Processing Record 35 of Set 10 | longyearbyen
# Processing Record 36 of Set 10 | chontalpa
# Processing Record 37 of Set 10 | werder
# Processing Record 38 of Set 10 | morant bay
# Processing Record 39 of Set 10 | evensk
# Processing Record 40 of Set 10 | colquiri
# Processing Record 41 of Set 10 | santa cruz
# Processing Record 42 of Set 10 | dicabisagan
# Processing Record 43 of Set 10 | talcahuano
# Processing Record 44 of Set 10 | povenets
# Processing Record 45 of Set 10 | oxapampa
# Processing Record 46 of Set 10 | pajapan
# Processing Record 47 of Set 10 | kamenica
# Processing Record 48 of Set 10 | maniago
# Processing Record 49 of Set 10 | broome
# Processing Record 50 of Set 10 | lahij
# Processing Record 1 of Set 11 | amahai
# Processing Record 2 of Set 11 | talas
# Processing Record 3 of Set 11 | altea
# Processing Record 4 of Set 11 | ionia
# Processing Record 5 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 11 | inhambane
# Processing Record 7 of Set 11 | miri
# Processing Record 8 of Set 11 | tacuati
# Processing Record 9 of Set 11 | ha tinh
# Processing Record 10 of Set 11 | maniitsoq
# Processing Record 11 of Set 11 | kununurra
# Processing Record 12 of Set 11 | vredendal
# Processing Record 13 of Set 11 | jackson
# Processing Record 14 of Set 11 | xiongshi
# City not found. Skipping...
# Processing Record 15 of Set 11 | guerrero
# Processing Record 16 of Set 11 | kashin
# Processing Record 17 of Set 11 | beruwala
# Processing Record 18 of Set 11 | sakakah
# Processing Record 19 of Set 11 | dudinka
# Processing Record 20 of Set 11 | taltal
# Processing Record 21 of Set 11 | aksarka
# Processing Record 22 of Set 11 | kaitangata
# Processing Record 23 of Set 11 | doka
# Processing Record 24 of Set 11 | grootfontein
# Processing Record 25 of Set 11 | causapscal
# Processing Record 26 of Set 11 | rafai
# Processing Record 27 of Set 11 | viransehir
# Processing Record 28 of Set 11 | kargil
# Processing Record 29 of Set 11 | lander
# Processing Record 30 of Set 11 | almaty
# Processing Record 31 of Set 11 | usinsk
# Processing Record 32 of Set 11 | ancud
# Processing Record 33 of Set 11 | amga
# Processing Record 34 of Set 11 | beberibe
# Processing Record 35 of Set 11 | santa isabel
# Processing Record 36 of Set 11 | yining
# Processing Record 37 of Set 11 | teguldet
# Processing Record 38 of Set 11 | huazolotitlan
# City not found. Skipping...
# Processing Record 39 of Set 11 | wangqing
# Processing Record 40 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 11 | hamilton
# Processing Record 42 of Set 11 | andilamena
# Processing Record 43 of Set 11 | okhotsk
# Processing Record 44 of Set 11 | hami
# Processing Record 45 of Set 11 | paraopeba
# Processing Record 46 of Set 11 | qaqortoq
# Processing Record 47 of Set 11 | dauphin
# Processing Record 48 of Set 11 | taganak
# Processing Record 49 of Set 11 | angoche
# Processing Record 50 of Set 11 | san vicente
# Processing Record 1 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 12 | shingu
# Processing Record 3 of Set 12 | stornoway
# Processing Record 4 of Set 12 | jalingo
# Processing Record 5 of Set 12 | northam
# Processing Record 6 of Set 12 | riberalta
# Processing Record 7 of Set 12 | ixtapa
# Processing Record 8 of Set 12 | arman
# Processing Record 9 of Set 12 | shenjiamen
# Processing Record 10 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 12 | wawa
# Processing Record 12 of Set 12 | jalu
# Processing Record 13 of Set 12 | saint-pierre
# Processing Record 14 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 15 of Set 12 | marsh harbour
# Processing Record 16 of Set 12 | high level
# Processing Record 17 of Set 12 | wolsztyn
# Processing Record 18 of Set 12 | gravelbourg
# Processing Record 19 of Set 12 | mata
# Processing Record 20 of Set 12 | talara
# Processing Record 21 of Set 12 | araouane
# Processing Record 22 of Set 12 | narasannapeta
# Processing Record 23 of Set 12 | kirkwood
# Processing Record 24 of Set 12 | linjiang
# Processing Record 25 of Set 12 | nhulunbuy
# Processing Record 26 of Set 12 | uvarovka
# Processing Record 27 of Set 12 | laguna
# Processing Record 28 of Set 12 | alta floresta
# Processing Record 29 of Set 12 | nelson bay
# Processing Record 30 of Set 12 | sorong
# Processing Record 31 of Set 12 | kahului
# Processing Record 32 of Set 12 | macas
# Processing Record 33 of Set 12 | skjern
# Processing Record 34 of Set 12 | steinau
# Processing Record 35 of Set 12 | erzin
# Processing Record 36 of Set 12 | punta alta
# Processing Record 37 of Set 12 | jinchang
# Processing Record 38 of Set 12 | viedma
# Processing Record 39 of Set 12 | shache
# Processing Record 40 of Set 12 | rawson
# Processing Record 41 of Set 12 | birao
# Processing Record 42 of Set 12 | lianran
# Processing Record 43 of Set 12 | vangaindrano
# Processing Record 44 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 12 | goderich
# Processing Record 46 of Set 12 | manggar
# Processing Record 47 of Set 12 | bella union
# Processing Record 48 of Set 12 | saint-augustin
# Processing Record 49 of Set 12 | sainte-anne-des-monts
# Processing Record 50 of Set 12 | acarau
# Processing Record 1 of Set 13 | muros
# Processing Record 2 of Set 13 | elizabeth city
# Processing Record 3 of Set 13 | nouadhibou
# Processing Record 4 of Set 13 | vokhtoga
# Processing Record 5 of Set 13 | karousades
# City not found. Skipping...
# Processing Record 6 of Set 13 | basco
# Processing Record 7 of Set 13 | nanning
# Processing Record 8 of Set 13 | fukue
# Processing Record 9 of Set 13 | majdanpek
# Processing Record 10 of Set 13 | ternate
# Processing Record 11 of Set 13 | dumai
# Processing Record 12 of Set 13 | souillac
# Processing Record 13 of Set 13 | sabha
# Processing Record 14 of Set 13 | navirai
# Processing Record 15 of Set 13 | taranagar
# Processing Record 16 of Set 13 | sangmelima
# Processing Record 17 of Set 13 | sur
# Processing Record 18 of Set 13 | chernyshevskiy
# Processing Record 19 of Set 13 | rosarito
# Processing Record 20 of Set 13 | tucurui
# Processing Record 21 of Set 13 | sri aman
# Processing Record 22 of Set 13 | hailey
# Processing Record 23 of Set 13 | parana
# Processing Record 24 of Set 13 | koumac
# Processing Record 25 of Set 13 | solton
# Processing Record 26 of Set 13 | churintzio
# Processing Record 27 of Set 13 | xuddur
# Processing Record 28 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 13 | churu
# Processing Record 30 of Set 13 | sibolga
# Processing Record 31 of Set 13 | hengyang
# Processing Record 32 of Set 13 | sambava
# Processing Record 33 of Set 13 | byron bay
# Processing Record 34 of Set 13 | mukhen
# Processing Record 35 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 13 | westport
# Processing Record 37 of Set 13 | aschersleben
# Processing Record 38 of Set 13 | acapulco
# Processing Record 39 of Set 13 | vanimo
# Processing Record 40 of Set 13 | marzuq
# Processing Record 41 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | werda
# Processing Record 43 of Set 13 | porto belo
# Processing Record 44 of Set 13 | foam lake
# Processing Record 45 of Set 13 | qasigiannguit
# Processing Record 46 of Set 13 | dingle
# Processing Record 47 of Set 13 | sao jose da coroa grande
# Processing Record 48 of Set 13 | maceio
# Processing Record 49 of Set 13 | novosheshminsk
# Processing Record 50 of Set 13 | catamarca
# Processing Record 1 of Set 14 | buhe
# Processing Record 2 of Set 14 | te anau
# Processing Record 3 of Set 14 | tawang
# Processing Record 4 of Set 14 | manaure
# Processing Record 5 of Set 14 | velestinon
# City not found. Skipping...
# Processing Record 6 of Set 14 | coralville
# Processing Record 7 of Set 14 | trail
# Processing Record 8 of Set 14 | gravdal
# Processing Record 9 of Set 14 | merauke
# Processing Record 10 of Set 14 | mount isa
# Processing Record 11 of Set 14 | bontang
# Processing Record 12 of Set 14 | ornskoldsvik
# Processing Record 13 of Set 14 | ejido
# Processing Record 14 of Set 14 | san alberto
# Processing Record 15 of Set 14 | waldoboro
# Processing Record 16 of Set 14 | alikovo
# Processing Record 17 of Set 14 | gemena
# Processing Record 18 of Set 14 | sorland
# Processing Record 19 of Set 14 | saint-francois
# Processing Record 20 of Set 14 | treinta y tres
# Processing Record 21 of Set 14 | zwedru
# Processing Record 22 of Set 14 | mutis
# Processing Record 23 of Set 14 | oudtshoorn
# Processing Record 24 of Set 14 | awjilah
# Processing Record 25 of Set 14 | pilao arcado
# City not found. Skipping...
# Processing Record 26 of Set 14 | quepos
# Processing Record 27 of Set 14 | turangi
# Processing Record 28 of Set 14 | ambovombe
# Processing Record 29 of Set 14 | abnub
# Processing Record 30 of Set 14 | manuel doblado
# City not found. Skipping...
# Processing Record 31 of Set 14 | ourinhos
# Processing Record 32 of Set 14 | hasaki
# Processing Record 33 of Set 14 | tarrafal
# Processing Record 34 of Set 14 | mabaruma
# Processing Record 35 of Set 14 | nizhniy kuranakh
# Processing Record 36 of Set 14 | tura
# Processing Record 37 of Set 14 | agua prieta
# Processing Record 38 of Set 14 | manbij
# Processing Record 39 of Set 14 | hinganghat
# Processing Record 40 of Set 14 | tuatapere
# Processing Record 41 of Set 14 | azle
# Processing Record 42 of Set 14 | kilindoni
# Processing Record 43 of Set 14 | banjar
# Processing Record 44 of Set 14 | khash
# Processing Record 45 of Set 14 | carutapera
# Processing Record 46 of Set 14 | mizan teferi
# Processing Record 47 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 49 of Set 14 | lima
# Processing Record 50 of Set 14 | kisangani
# Processing Record 1 of Set 15 | port hawkesbury
# Processing Record 2 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 3 of Set 15 | inuvik
# Processing Record 4 of Set 15 | touros
# Processing Record 5 of Set 15 | abalak
# Processing Record 6 of Set 15 | quixada
# Processing Record 7 of Set 15 | waitara
# Processing Record 8 of Set 15 | assela
# City not found. Skipping...
# Processing Record 9 of Set 15 | jibuti
# Processing Record 10 of Set 15 | portel
# Processing Record 11 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 12 of Set 15 | mingaora
# Processing Record 13 of Set 15 | ondjiva
# Processing Record 14 of Set 15 | port-cartier
# Processing Record 15 of Set 15 | epiniana
# Processing Record 16 of Set 15 | florence
# Processing Record 17 of Set 15 | uray
# Processing Record 18 of Set 15 | nyaunglebin
# Processing Record 19 of Set 15 | rocky mountain house
# Processing Record 20 of Set 15 | norman
# Processing Record 21 of Set 15 | siyabuswa
# Processing Record 22 of Set 15 | ocos
# Processing Record 23 of Set 15 | sredneuralsk
# Processing Record 24 of Set 15 | pangai
# Processing Record 25 of Set 15 | elliot lake
# Processing Record 26 of Set 15 | houston
# Processing Record 27 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 15 | key west
# Processing Record 29 of Set 15 | marawi
# Processing Record 30 of Set 15 | mezhdurechensk
# Processing Record 31 of Set 15 | chotebor
# Processing Record 32 of Set 15 | banda aceh
# Processing Record 33 of Set 15 | cerrito
# Processing Record 34 of Set 15 | lar
# Processing Record 35 of Set 15 | atambua
# Processing Record 36 of Set 15 | yumen
# Processing Record 37 of Set 15 | betare oya
# Processing Record 38 of Set 15 | porto torres
# Processing Record 39 of Set 15 | saldanha
# Processing Record 40 of Set 15 | pudozh
# Processing Record 41 of Set 15 | qusar
# Processing Record 42 of Set 15 | shu
# Processing Record 43 of Set 15 | wajima
# Processing Record 44 of Set 15 | ngerengere
# Processing Record 45 of Set 15 | kurilsk
# Processing Record 46 of Set 15 | hokitika
# Processing Record 47 of Set 15 | prince rupert
# Processing Record 48 of Set 15 | janow lubelski
# Processing Record 49 of Set 15 | locri
# Processing Record 50 of Set 15 | perbaungan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Meshcherino  55.1957   38.3600     23.00        86          90
# 1       Butaritari   3.0707  172.7902     81.52        83           9
# 2          Mataura -46.1927  168.8643     57.00        74          40
# 3      Tuktoyaktuk  69.4541 -133.0374    -11.20        77          20
# 4     Saint George  37.1041 -113.5841     57.00        27           1
# 5           Mehamn  71.0357   27.8492     26.60        63           0
# 6           Beidao  34.5686  105.8933     17.46        65          10
# 7           Olinda  -8.0089  -34.8553     80.60        69          40
# 8  Arraial Do Cabo -22.9661  -42.0278     84.20        74           0
# 9       Chokurdakh  70.6333  147.9167    -12.30        90          97
#
#    Wind Speed Country                 Date Weather Description
# 0        6.71      RU  2021-01-07 21:30:43                mist
# 1       20.04      KI  2021-01-07 21:30:43          light rain
# 2        1.99      NZ  2021-01-07 21:30:43    scattered clouds
# 3        9.22      CA  2021-01-07 21:30:44          few clouds
# 4        0.98      US  2021-01-07 21:30:44           clear sky
# 5       12.66      NO  2021-01-07 21:30:44           clear sky
# 6        0.49      CN  2021-01-07 21:30:44           clear sky
# 7        9.22      BR  2021-01-07 21:30:44    scattered clouds
# 8        9.22      BR  2021-01-07 21:30:45           clear sky
# 9        7.23      RU  2021-01-07 21:30:45     overcast clouds

# %%
new_headers = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", 
               "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_headers]

city_data_df
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0       Meshcherino      RU  2021-01-07 21:30:43  55.1957   38.3600     23.00
# 1        Butaritari      KI  2021-01-07 21:30:43   3.0707  172.7902     81.52
# 2           Mataura      NZ  2021-01-07 21:30:43 -46.1927  168.8643     57.00
# 3       Tuktoyaktuk      CA  2021-01-07 21:30:44  69.4541 -133.0374    -11.20
# 4      Saint George      US  2021-01-07 21:30:44  37.1041 -113.5841     57.00
# ..              ...     ...                  ...      ...       ...       ...
# 685        Hokitika      NZ  2021-01-07 21:33:29 -42.7167  170.9667     65.52
# 686   Prince Rupert      CA  2021-01-07 21:33:29  54.3161 -130.3201     42.80
# 687  Janow Lubelski      PL  2021-01-07 21:33:29  50.7070   22.4104     30.99
# 688           Locri      IT  2021-01-07 21:33:30  38.2414   16.2623     62.60
# 689      Perbaungan      ID  2021-01-07 21:33:30   3.5679   98.9560     75.20
#
#      Humidity  Cloudiness  Wind Speed Weather Description
# 0          86          90        6.71                mist
# 1          83           9       20.04          light rain
# 2          74          40        1.99    scattered clouds
# 3          77          20        9.22          few clouds
# 4          27           1        0.98           clear sky
# ..        ...         ...         ...                 ...
# 685        75          97        2.71     overcast clouds
# 686        87          90       12.66          light rain
# 687        94          31        6.38    scattered clouds
# 688        63           0       11.50           clear sky
# 689       100          40        3.44    scattered clouds
#
# [690 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
